# %%
# Google Colab에 NanumGothic 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# matplotlib.font_manager 임포트
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# 설치된 폰트 확인 및 matplotlib에 적용
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumGothic')

print("폰트 설정 완료")
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# 폰트 설정 완료

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# CSV 파일 읽기
df = pd.read_csv('/content/가동률지수.csv')

# 날짜 형식을 datetime으로 변환
df['date'] = pd.to_datetime(df['date'], format='%Y/%m')

# 결과 저장용 데이터프레임
all_forecasts = []

# LSTM 모델을 위한 데이터 준비 함수
def prepare_data(series, n_steps):
    X, y = [], []
    for i in range(len(series)):
        end_ix = i + n_steps
        if end_ix > len(series) - 1:
            break
        seq_x, seq_y = series[i:end_ix], series[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# LSTM 모델 학습 및 예측 함수
def lstm_forecast(series, n_steps, n_forecast):
    scaler = MinMaxScaler(feature_range=(0, 1))
    series_scaled = scaler.fit_transform(series.values.reshape(-1, 1))
    X, y = prepare_data(series_scaled, n_steps)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(n_steps, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=300, verbose=0)

    x_input = series_scaled[-n_steps:].reshape((1, n_steps, 1))
    forecast = []
    for _ in range(n_forecast):
        yhat = model.predict(x_input, verbose=0)
        forecast.append(yhat[0][0])
        x_input = np.append(x_input[:, 1:, :], yhat.reshape((1, 1, 1)), axis=1)

    forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1)).flatten()
    return forecast

# 모든 열에 대해 LSTM 모델을 적용
n_steps = 12  # 과거 12개월 데이터 사용
n_forecast = 60  # 향후 60개월 예측
prediction_months = pd.date_range(start='2024-05', periods=n_forecast, freq='M')

for column in df.columns[1:]:
    series = df[column]
    forecast = lstm_forecast(series, n_steps, n_forecast)

    forecast_df = pd.DataFrame({'date': prediction_months, column: forecast})
    all_forecasts.append(forecast_df.set_index('date'))

    # 예측 결과 시각화
    plt.figure(figsize=(10, 6))
    plt.plot(df['date'], df[column], marker='o', label='실제 가동률 지수')
    plt.plot(prediction_months, forecast, marker='x', linestyle='--', label='예측 가동률 지수')
    plt.title(f'{column} 가동률 지수 예측')
    plt.xlabel('연도')
    plt.ylabel('가동률 지수')
    plt.legend()
    plt.grid(True)
    plt.show()

# 모든 예측 결과 병합
final_forecast = pd.concat(all_forecasts, axis=1)

# 성장률 계산
growth_rates = final_forecast.pct_change() * 100

# 성장률 및 예측 가동률 지수 테이블 저장
result = pd.concat([df.set_index('date'), final_forecast])
growth_rates.to_csv('lstm_growth_rates_and_forecasts.csv')

# 성장률 및 예측 가동률 지수 테이블 출력
from IPython.display import display
display(result)

print("성장률 및 예측 가동률 지수 테이블이 'lstm_growth_rates_and_forecasts.csv' 파일로 저장되었습니다.")
# Out:
#               평균가동률 지수    화학물질 및 화학제품    전자부품, 컴퓨터, 영상음향 및 통신장비      반도체 제조업  \
# date
# 2000-01-01  104.665314     108.350000                115.981000    67.777000
# 2000-02-01  103.853955     102.249000                107.236000    61.884000
# 2000-03-01  104.935767     113.751000                118.193000    67.788000
# 2000-04-01  103.177823     106.654000                115.392000    73.883000
# 2000-05-01  107.910751     105.528000                117.046000    76.755000
# ...                ...            ...                       ...          ...
# 2028-12-31  109.867020     102.022003                 92.903793    71.742607
# 2029-01-31  110.091225     102.136246                 92.875092    71.738564
# 2029-02-28  110.318085     102.248970                 92.850227    71.734512
# 2029-03-31  110.547630     102.362129                 92.829628    71.730896
# 2029-04-30  110.779907     102.474419                 92.812630    71.727989
#
#                 전자부품 제조업    전기장비 제조업      일차전지 및 축전지 제조업      기타 전기장비 제조업  \
# date
# 2000-01-01     97.866000   98.144000           61.532000        52.595000
# 2000-02-01     87.227000   91.681000           54.926000        46.275000
# 2000-03-01     94.909000  102.487000           67.826000        57.247000
# 2000-04-01     92.301000   97.334000           57.798000        44.546000
# 2000-05-01     98.847000  102.334000           60.882000        63.090000
# ...                  ...         ...                 ...              ...
# 2028-12-31     81.106453   97.064331          103.830772       126.524345
# 2029-01-31     81.094841   96.643608          104.153206       119.499565
# 2029-02-28     81.083534   96.358994          104.468521       121.103439
# 2029-03-31     81.071594   96.393517          104.766243       121.876991
# 2029-04-30     81.058525   96.622032          105.056564       114.714928
#
#                 자동차용 엔진 및 자동차 제조업
# date
# 2000-01-01             100.797000
# 2000-02-01              90.203000
# 2000-03-01             104.767000
# 2000-04-01              71.917000
# 2000-05-01             115.252000
# ...                           ...
# 2028-12-31             122.255249
# 2029-01-31             105.458595
# 2029-02-28             109.244064
# 2029-03-31             142.600128
# 2029-04-30             146.263535
#
# [352 rows x 9 columns]
# 성장률 및 예측 가동률 지수 테이블이 'lstm_growth_rates_and_forecasts.csv' 파일로 저장되었습니다.

# %% [markdown]
# ## 가동률지수 (Operating Rate Index):
#
#   - 정의: 가동률지수는 실제 생산된 생산량을 최대 생산 가능량과 비교하여 나타낸 지수입니다. 즉, 실제로 얼마나 공장이나 설비가 가동되고 있는지를 보여줍니다.
#   - 용도: 이 지수는 경제의 실제 가동 상태를 파악하는 데 유용합니다. 높은 가동률은 경제가 활발히 돌아가고 있음을, 낮은 가동률은 경기 침체나 과잉 생산설비 등을 나타낼 수 있습니다.
#   - 계산 방법: 실제 생산량을 최대 생산 가능량으로 나눈 후, 이를 백분율로 환산하여 지수화합니다. 기준년도인 2020년의 가동률을 100으로 설정하여 비교합니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 읽기
df = pd.read_csv('/content/가동률지수.csv')

# 첫 번째 열을 인덱스로 설정
df.set_index('date', inplace=True)

# 인덱스를 datetime 형식으로 변환
df.index = pd.to_datetime(df.index, format='%Y/%m')

# 업종별 가동률지수 시계열 그래프
plt.figure(figsize=(14, 7))
for column in df.columns:
    plt.plot(df.index, df[column], marker='o', label=column)
plt.title('업종별 가동률지수 시계열 그래프')
plt.xlabel('연도')
plt.ylabel('가동률지수')
plt.legend()
plt.grid(True)
plt.show()
